# %%
import json
import os

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter

from transformers import T5Tokenizer, MT5ForConditionalGeneration, AdamW, get_linear_schedule_with_warmup

# Google's Official Preprocess Codes
# https://github.com/google-research/language/blob/master/language/totto/baseline_preprocessing/preprocess_utils.py
from preprocess_utils import get_highlighted_subtable, linearize_subtable

# %%
# Train Config
device=torch.device('cpu')
lr=3e-1
batch_size=8 # 4(max 6) for 't5-large' and make 'accumulation_steps' larger
accumulation_steps=1
epochs=20

# Prompt Config
prompt_len=100
hidden_dim=768

# %%
# Pre-Trained T5 Tokenizer
tokenizer=T5Tokenizer.from_pretrained('google/mt5-base')
# Add Special Tokens: Table Tags
tokenizer.add_special_tokens({
    'additional_special_tokens': [
        '|',
        ':',
    ]
})
# Pre-Trained T5 Model
pretrained = MT5ForConditionalGeneration.from_pretrained('google/mt5-base').to(device)
# Resize PLM's Embedding Layer
pretrained.resize_token_embeddings(len(tokenizer))
# Freeze LM
for param in pretrained.parameters():
    param.requires_grad=False

# %%
class WebNLGDataset(Dataset):
    
    def __init__(self, tokenizer, raw_path='../webnlg_data/release_v3.0/ru', language='en', data_path='../webnlg_data/preprocessed', split='train'):
        
        if not os.path.exists(f'{data_path}/{split}.json'):
            b = Benchmark()
            files = select_files(raw_path)
            b.fill_benchmark(files)
            b.b2json(data_path, f'{split}.json')
        
        with open(f'{data_path}/{split}.json', 'r') as f:
            dataset = json.load(f)
            entries = dataset['entries']

        full_rela_lst = []
        full_src_lst = []
        full_tgt_lst = []
        for i, entry in enumerate(entries):
            sents = entry[str(i + 1)]['lexicalisations']
            triples = entry[str(i + 1)]['modifiedtripleset']
            
            rela_lst = []
            temp_triples = ''
            for j, tripleset in enumerate(triples):
                subj, rela, obj = tripleset['subject'], tripleset['property'], tripleset['object']
                rela_lst.append(rela)
                temp_triples += ' | '
                temp_triples += '{} : {} : {}'.format(subj, rela, obj)

            for sent in sents:
                if sent["lang"] == language:
                    full_tgt_lst.append(sent["lex"])
                    full_src_lst.append(temp_triples)
                    full_rela_lst.append(rela_lst)
                    if split == 'dev':
                        break
            
        assert len(full_rela_lst) == len(full_src_lst)
        assert len(full_rela_lst) == len(full_tgt_lst)

        self.examples = []
        self.targets = []
        for src, tgt in zip(full_src_lst, full_tgt_lst):
            src = tokenizer.encode(src)
            if len(src)>512:
                # Truncate
                encoded = src[:511] + [tokenizer.eos_token_id]
            self.examples.append(src)
    
            tgt = tokenizer.encode(tgt)
            self.targets.append(tgt)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        return self.examples[idx], self.targets[idx]

# %%
def collate_fn(batch):
    """
    Same Sequence Length on Same Batch
    """
    max_len_data=0
    max_len_label=0
    for data, label in batch:
        if len(data)>max_len_data: max_len_data=len(data)
        if len(label)>max_len_label: max_len_label=len(label)
            
    datas=[]
    attn_masks=[]
    labels=[]
    for data, label in batch:
        data.extend([tokenizer.pad_token_id]*(max_len_data-len(data)))
        datas.append(data)
        
        attn_mask=[int(e!=tokenizer.pad_token_id) for e in data]
        attn_masks.append(attn_mask)
        
        label.extend([-100]*(max_len_label-len(label)))
        labels.append(label)
        
    return torch.tensor(datas), torch.tensor(attn_masks), torch.tensor(labels)

# %%
dataset_train = WebNLGDataset(tokenizer=tokenizer)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

dataset_dev = WebNLGDataset(tokenizer=tokenizer, split='dev', )
dataloader_dev = DataLoader(dataset_dev, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
class PromptTuning(nn.Module):
    """
    """
    def __init__(self, pretrained_config, prompt_len=20, hidden_dim=256):
        super().__init__()
        
        # Config of Pre-Trained LM
        self.pretrained_config=pretrained_config
        
        # torch.tensor([0, 1, 2, .. , prompt_len-1])
        self.pre_prompt=torch.arange(prompt_len)
        # Embedding
        self.embd=nn.Embedding(num_embeddings=prompt_len, embedding_dim=pretrained_config.d_model)
        # Reparameterization
        self.reparam=nn.Sequential(
            nn.Linear(pretrained_config.d_model, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, pretrained_config.d_model)
        )
        
    def forward(self, batch_size, device):
        # Shape: batch_size, prompt_len
        prompt=self.pre_prompt.unsqueeze(0).expand(batch_size, -1).to(device)
        # Shape: batch_size, prompt_len, d_model
        prompt=self.embd(prompt)
        # Shape: batch_size, prompt_len, d_model
        prompt=self.reparam(prompt)
        
        return prompt

# %%
def evaluate_model(model, epoch):
    # PLM (Eval Mode)
    pretrained.eval()

    # Trained Model
    model = model.to(device)
    model.eval()

    # Generation
    if os.path.exists(f'../webnlg_data/multilingual_prefix_tuning/epoch{epoch}.txt'):
        os.remove(f'../webnlg_data/multilingual_prefix_tuning/epoch{epoch}.txt')
    f=open(f'../webnlg_data/multilingual_prefix_tuning/epoch{epoch}.txt', 'a')

    with torch.no_grad():
        for idx, (data, attn_mask, _) in enumerate(dataloader_dev):
            if (idx+1)%100==0: print(batch_size*(idx+1), 'generated')

            data=data.to(device)
            attn_mask=attn_mask.to(device)

            # Get Prompt
            prompt=model(batch_size=data.shape[0], device=device)

            # Beam Search
            outputs=pretrained.generate(
                data,
                max_length=300,
                num_beams=5,
                early_stopping=True,
                prompt=prompt
            )

            for generation in tokenizer.batch_decode(outputs, skip_special_tokens=True):
                f.write(generation+'\n')

    f.close()

# %%
# Model: Prompt Tuning
model=PromptTuning(pretrained_config=pretrained.config, prompt_len=prompt_len, hidden_dim=hidden_dim)

# Optim, Scheduler
optimizer=AdamW(model.parameters(), lr=lr)
# NO Warm-Up
scheduler=get_linear_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=int(epochs*len(dataset_train)/(accumulation_steps*batch_size))
)

# TensorBoard: Logging
writer=SummaryWriter()
step_global=0

for epoch in range(epochs):
    # Train Phase
    model.train()
    model.to(device)
    
    loss_train=0
    optimizer.zero_grad()
    
    for step, (data, attn_mask, label) in enumerate(dataloader_train):
        data=data.to(device)
        attn_mask=attn_mask.to(device)
        label=label.to(device)
        
        prompt=model(batch_size=data.shape[0] , device=device)
        outputs=pretrained(input_ids=data, attention_mask=attn_mask, labels=label, prompt=prompt)
        
        loss=outputs[0]/accumulation_steps
        loss.backward()
        
        loss_train+=loss.item()
        
        if (step+1)%accumulation_steps==0:
            step_global+=1
            
            # TensorBoard
            writer.add_scalar(
                f'loss_train/MT5-base_Prompt-Tuning_prompt-len{prompt_len}_hidden-dim{hidden_dim}_lr{lr}_batch{int(accumulation_steps*batch_size)}_epoch{epochs}',
                loss_train,
                step_global
            )
            # Console
            if step_global%1000==0:
                print(f'epoch {epoch+1} step {step_global} loss_train {loss_train:.4f}')
            # Set Loss to 0
            loss_train=0
            
            optimizer.step()
            scheduler.step()
            
            optimizer.zero_grad()
            
    # Save Model
    model.to(torch.device('cpu'))
    model_name = f'MT5-base_Prompt-Tuning_prompt-len{prompt_len}_hidden-dim{hidden_dim}_lr{lr}_batch{int(accumulation_steps*batch_size)}_epoch{epoch+1}of{epochs}.pt'
    torch.save(model, f'../model/{model_name}')
    evaluate_model(model, epoch)
# Out:
# /Users/davidvos/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 17>()
#      28 label=label.to(device)
#      30 prompt=model(batch_size=data.shape[0] , device=device)
# ---> 31 outputs=pretrained(input_ids=data, attention_mask=attn_mask, labels=label, prompt=prompt)
#      33 loss=outputs[0]/accumulation_steps
#      34 loss.backward()
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/modeling_t5.py:1617, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, prompt)
#    1614 # Encode if needed (training, first prediction pass)
#    1615 if encoder_outputs is None:
#    1616     # Convert encoder inputs in embeddings if needed
# -> 1617     encoder_outputs = self.encoder(
#    1618         input_ids=input_ids,
#    1619         attention_mask=attention_mask,
#    1620         inputs_embeds=inputs_embeds,
#    1621         head_mask=head_mask,
#    1622         output_attentions=output_attentions,
#    1623         output_hidden_states=output_hidden_states,
#    1624         return_dict=return_dict,
#    1625         #
#    1626         prompt=prompt,
#    1627     )
#    1628 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#    1629     encoder_outputs = BaseModelOutput(
#    1630         last_hidden_state=encoder_outputs[0],
#    1631         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1632         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1633     )
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/modeling_t5.py:1047, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, prompt)
#    1034     layer_outputs = checkpoint(
#    1035         create_custom_forward(layer_module),
#    1036         hidden_states,
#    (...)
#    1044         None,  # past_key_value is always None with gradient checkpointing
#    1045     )
#    1046 else:
# -> 1047     layer_outputs = layer_module(
#    1048         hidden_states,
#    1049         attention_mask=extended_attention_mask,
#    1050         position_bias=position_bias,
#    1051         encoder_hidden_states=encoder_hidden_states,
#    1052         encoder_attention_mask=encoder_extended_attention_mask,
#    1053         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1054         layer_head_mask=layer_head_mask,
#    1055         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1056         past_key_value=past_key_value,
#    1057         use_cache=use_cache,
#    1058         output_attentions=output_attentions,
#    1059     )
#    1061 # layer_outputs is a tuple with:
#    1062 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1063 if use_cache is False:
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/modeling_t5.py:717, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     714     attention_outputs = attention_outputs + cross_attention_outputs[2:]
#     716 # Apply Feed Forward layer
# --> 717 hidden_states = self.layer[-1](hidden_states)
#     719 # clamp inf values to enable fp16 training
#     720 if hidden_states.dtype == torch.float16 and torch.isinf(hidden_states).any():
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/modeling_t5.py:327, in T5LayerFF.forward(self, hidden_states)
#     325 def forward(self, hidden_states):
#     326     forwarded_states = self.layer_norm(hidden_states)
# --> 327     forwarded_states = self.DenseReluDense(forwarded_states)
#     328     hidden_states = hidden_states + self.dropout(forwarded_states)
#     329     return hidden_states
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/modeling_t5.py:303, in T5DenseGatedGeluDense.forward(self, hidden_states)
#     301 def forward(self, hidden_states):
#     302     hidden_gelu = self.gelu_act(self.wi_0(hidden_states))
# --> 303     hidden_linear = self.wi_1(hidden_states)
#     304     hidden_states = hidden_gelu * hidden_linear
#     305     hidden_states = self.dropout(hidden_states)
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
