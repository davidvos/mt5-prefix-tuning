# %%
import json
import os

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter

from transformers import T5Tokenizer, MT5ForConditionalGeneration, AdamW, get_linear_schedule_with_warmup

# Google's Official Preprocess Codes
# https://github.com/google-research/language/blob/master/language/totto/baseline_preprocessing/preprocess_utils.py
from preprocess_utils import get_highlighted_subtable, linearize_subtable

# %%
# Train Config
device=torch.device('cpu')
lr=3e-1
batch_size=8 # 4(max 6) for 't5-large' and make 'accumulation_steps' larger
accumulation_steps=1
epochs=20

# Prompt Config
prompt_len=100
hidden_dim=768

# %%
# Pre-Trained T5 Tokenizer
tokenizer=T5Tokenizer.from_pretrained('google/mt5-base')
# Add Special Tokens: Table Tags
tokenizer.add_special_tokens({
    'additional_special_tokens': [
        '|',
        ':',
    ]
})
# Pre-Trained T5 Model
pretrained = MT5ForConditionalGeneration.from_pretrained('google/mt5-base').to(device)
# Resize PLM's Embedding Layer
pretrained.resize_token_embeddings(len(tokenizer))
# Freeze LM
for param in pretrained.parameters():
    param.requires_grad=False

# %%
class WebNLGDataset(Dataset):
    
    def __init__(self, tokenizer, raw_path='../webnlg_data/release_v3.0/ru', language='en', data_path='../webnlg_data/preprocessed', split='train'):
        
        if not os.path.exists(f'{data_path}/{split}.json'):
            b = Benchmark()
            files = select_files(raw_path)
            b.fill_benchmark(files)
            b.b2json(data_path, f'{split}.json')
        
        with open(f'{data_path}/{split}.json', 'r') as f:
            dataset = json.load(f)
            entries = dataset['entries']

        full_rela_lst = []
        full_src_lst = []
        full_tgt_lst = []
        for i, entry in enumerate(entries):
            sents = entry[str(i + 1)]['lexicalisations']
            triples = entry[str(i + 1)]['modifiedtripleset']
            
            rela_lst = []
            temp_triples = ''
            for j, tripleset in enumerate(triples):
                subj, rela, obj = tripleset['subject'], tripleset['property'], tripleset['object']
                rela_lst.append(rela)
                temp_triples += ' | '
                temp_triples += '{} : {} : {}'.format(subj, rela, obj)

            for sent in sents:
                if sent["lang"] == language:
                    full_tgt_lst.append(sent["lex"])
                    full_src_lst.append(temp_triples)
                    full_rela_lst.append(rela_lst)
                    if split == 'dev':
                        break
            
        assert len(full_rela_lst) == len(full_src_lst)
        assert len(full_rela_lst) == len(full_tgt_lst)

        self.examples = []
        self.targets = []
        for src, tgt in zip(full_src_lst, full_tgt_lst):
            print(src)
            src = tokenizer.encode(src)
            if len(src)>512:
                # Truncate
                encoded = src[:511] + [tokenizer.eos_token_id]
            self.examples.append(src)
    
            print(tgt)
            tgt = tokenizer.encode(tgt)
            self.targets.append(tgt)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        return self.examples[idx], self.targets[idx]

# %%
class ToTToDataset(Dataset):
    def __init__(self, path_data, tokenizer):
        #
        self.data=[]
        self.label=[]
        
        # Load Dataset
        with open(path_data, 'r') as f:
            dataset=f.read().splitlines()
            f.close()
            
        for _data in dataset:
            data=json.loads(_data)
            
            # Preprocess
            subtable=get_highlighted_subtable(table=data['table'], cell_indices=data['highlighted_cells'], with_heuristic_headers=True)
            cells_linearized=linearize_subtable(
                subtable=subtable,
                table_page_title=data['table_page_title'],
                table_section_title=data['table_section_title']
            )
            
            # Encode
            print(cells_linearized)
            encoded=tokenizer.encode(cells_linearized)
            if len(encoded)>512:
                # Truncate
                encoded=encoded[:511]+[tokenizer.eos_token_id]
            self.data.append(encoded)
            print(data['sentence_annotations'][0]['final_sentence'])
            self.label.append(tokenizer.encode(data['sentence_annotations'][0]['final_sentence']))
            
        print(len(self.data), 'datas')
        print(len(self.label), 'labels')
        
    def __getitem__(self, idx):
        return self.data[idx], self.label[idx]
        
    def __len__(self):
        return len(self.data)

# %%
def collate_fn(batch):
    """
    Same Sequence Length on Same Batch
    """
    max_len_data=0
    max_len_label=0
    for data, label in batch:
        if len(data)>max_len_data: max_len_data=len(data)
        if len(label)>max_len_label: max_len_label=len(label)
            
    datas=[]
    attn_masks=[]
    labels=[]
    for data, label in batch:
        data.extend([tokenizer.pad_token_id]*(max_len_data-len(data)))
        datas.append(data)
        
        attn_mask=[int(e!=tokenizer.pad_token_id) for e in data]
        attn_masks.append(attn_mask)
        
        label.extend([-100]*(max_len_label-len(label)))
        labels.append(label)
        
    return torch.tensor(datas), torch.tensor(attn_masks), torch.tensor(labels)

# %%
dataset_train=WebNLGDataset(tokenizer=tokenizer)
dataloader_train=DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
# Out:
#  | Aarhus_Airport : cityServed : "Aarhus, Denmark"
# The Aarhus is the airport of Aarhus, Denmark.
#  | Aarhus_Airport : cityServed : "Aarhus, Denmark"
# Aarhus Airport serves the city of Aarhus, Denmark.
#  | Aarhus_Airport : cityServed : Aarhus
# Aarhus airport serves the city of Aarhus.
#  | Aarhus_Airport : elevationAboveTheSeaLevel : 25.0
# Aarhus Airport is 25 metres above sea level.
#  | Aarhus_Airport : elevationAboveTheSeaLevel : 25.0
# Aarhus airport is at an elevation of 25 metres above seal level.
#  | Aarhus_Airport : elevationAboveTheSeaLevel : 25.0
# Aarhus Airport is 25.0 metres above the sea level.
#  | Aarhus_Airport : location : Tirstrup
# Aarhus Airport is located in Tirstrup.
#  | Aarhus_Airport : location : Tirstrup
# The location of Aarhus Airport is Tirstrup.
#  | Aarhus_Airport : operatingOrganisation : "Aarhus Lufthavn A/S"
# Aarhus Airport is operated by Aarhus Lufthavn A/S.
#  | Aarhus_Airport : operatingOrganisation : "Aarhus Lufthavn A/S"
# Aarhus Lufthavn A/S is the operation organisation of Aarhus Airport.
#  | Aarhus_Airport : operatingOrganisation : Aktieselskab
# Aktieselskab is the operating organisation for Aarhus Airport.
#  | Aarhus_Airport : operatingOrganisation : Aktieselskab
# Aktieselskab operates Aarhus Airport.
#  | Aarhus_Airport : operatingOrganisation : Aktieselskab
# Aarhus Airport is operated by the Aktieselkab organisation.
#  | Aarhus_Airport : runwayLength : 2776.0
# Aarhus Airport runway length is 2776.0.
#  | Aarhus_Airport : runwayLength : 2776.0
# Aarhus Airport has a runway length of 2776.0.
#  | Aarhus_Airport : runwayLength : 2776.0
# The length of the runway at Aarhus Airport is 2776.0.
#  | Aarhus_Airport : runwayLength : 2777.0
# The runway length at Aarhus Airport is 2777.0 meters.
#  | Aarhus_Airport : runwayLength : 2777.0
# The runway length at Aarhus airport is 2777.0.
#  | Aarhus_Airport : runwayName : "10L/28R"
# Aarhus Airport runway name is 10L/28R.
#  | Aarhus_Airport : runwayName : "10L/28R"
# 10L/28R is the runway name of the Aarhus Airport.
#  | Aarhus_Airport : runwayName : "10L/28R"
# The runway name of Aarhus Airport is 10L/28R.
#  | Aarhus_Airport : runwayName : "10R/28L"
# The runway name at Aarhus Airport is "10R/28L".
#  | Aarhus_Airport : runwayName : "10R/28L"
# 10R/28L is the runway name at Aarhus airport,.
#  | Aarhus_Airport : runwayName : "10R/28L"
# The runway name of Aarhus Airport is 10R/28L.
#  | Abilene,_Texas : country : United_States
# Abilene, Texas is in the United States.
#  | Abilene,_Texas : country : United_States
# Abilene Texas is in the United States.
#  | Abilene,_Texas : country : United_States
# Abilene, Texas is located in the United States.
#  | Abilene,_Texas : isPartOf : Jones_County,_Texas
# Abilene, Texas is part of Jones County, Texas.
#  | Abilene,_Texas : isPartOf : Jones_County,_Texas
# Abilene is part of Jones County, Texas.
#  | Abilene,_Texas : isPartOf : Taylor_County,_Texas
# Abilene, Texas is part of Taylor County,Texas.
#  | Abilene,_Texas : isPartOf : Taylor_County,_Texas
# Abilene is a part of Taylor County, Texas.
#  | Abilene,_Texas : isPartOf : Taylor_County,_Texas
# Abilene, Texas is part of Taylor County, Texas.
#  | Abilene,_Texas : isPartOf : Texas
# Abilene, Texas is part of Texas.
#  | Abilene,_Texas : isPartOf : Texas
# Abilene is part of Texas.
#  | Abilene_Regional_Airport : 1stRunwayLengthFeet : 3678
# The length of the 1st runway at Abilene Regional airport is 3678 feet.
#  | Abilene_Regional_Airport : 1stRunwaySurfaceType : Asphalt
# The first runway at Abilene Regional Airport is made from asphalt.
#  | Abilene_Regional_Airport : 1stRunwaySurfaceType : Asphalt
# The 1st runway at Abilene Regional Airport is made of Asphalt.
#  | Abilene_Regional_Airport : 3rdRunwayLengthFeet : 7202
# The third runway at Abilene Regional Airport is 7,202 feet long.
#  | Abilene_Regional_Airport : 3rdRunwayLengthFeet : 7202
# The 3rd runway at Abilene Regional airport is 7202 feet.
#  | Abilene_Regional_Airport : 3rdRunwayLengthFeet : 7202
# The Abilene Regional Airport's 3rd runway length is ft is 7202.
#  | Abilene_Regional_Airport : icaoLocationIdentifier : "KABI"
# Abilene Regional Airport ICAO Location Identifier is KABI.
#  | Abilene_Regional_Airport : icaoLocationIdentifier : "KABI"
# KABI is the ICAO location identifier of Abilene Regional Airport.
#  | Abilene_Regional_Airport : icaoLocationIdentifier : "KABI"
# The ICAO Location Identifier of Abilene Regional Airport is KABI.
#  | Abilene_Regional_Airport : elevationAboveTheSeaLevel : 546
# Abilene Regional Airport elevation above the sea level in metres is 546.
#  | Abilene_Regional_Airport : elevationAboveTheSeaLevel : 546
# The Abilene Regional Airport is 546 metres above sea level.
#  | Abilene_Regional_Airport : elevationAboveTheSeaLevel : 546
# Abilene Regional Airport is located 546 metres above sea level.
#  | Abilene_Regional_Airport : locationIdentifier : "ABI"
# The location identifier for Abilene Regional airport is ABI.
#  | Abilene_Regional_Airport : locationIdentifier : "ABI"
# The Abilene Regional Airport's location id is "ABI".
#  | Abilene_Regional_Airport : locationIdentifier : "ABI"
# The location Identifier of Abilene Regional Airport is ABI.
#  | Abilene_Regional_Airport : runwayLength : 1121.0
# The runway length of Abilene Regional Airport is 1,121.
#  | Abilene_Regional_Airport : runwayLength : 1121.0
# Abilene Regional airport has a runway length of 1121.0.
#  | Abilene_Regional_Airport : runwayLength : 1121.0
# The runway length of Abilene Regional Airport is 1121.0.
#  | Abilene_Regional_Airport : runwayLength : 2194.0
# The runway length of Abilene Regional Airport is 2194.0.
#  | Abilene_Regional_Airport : runwayLength : 2195.0
# The runway length of Abilene Regional Airport is 2,195.
#  | Abilene_Regional_Airport : runwayLength : 2195.0
# The runway length of Abilene Regional Airport is 2195.0.
#  | Abilene_Regional_Airport : runwayName : "17L/35R"
# Abilene Regional Airport runway name is 17L/35R.
#  | Abilene_Regional_Airport : runwayName : "17L/35R"
# 17L/35R is the runway name of Abilene Regional Airport.
#  | Abilene_Regional_Airport : runwayName : "17L/35R"
# Abilene Regional Airport has the runway name 17L/35R.
#  | Abilene_Regional_Airport : runwayName : "17R/35L"
# 17R/35L is the runway name at Abilene Regional airport.
#  | Abilene_Regional_Airport : runwayName : "17R/35L"
# The name of the runway at Abilene Regional Airport is 17R/35L.
#  | Abilene_Regional_Airport : runwayName : "17R/35L"
# The runway name of Abilene Regional Airport is 17R/35L.
#  | Adirondack_Regional_Airport : 1stRunwayLengthFeet : 6573
# The length of the first runway at Adirondack Regional Airport is 6,573 feet.
#  | Adirondack_Regional_Airport : 1stRunwayLengthFeet : 6573
# 6573 feet is the length of the first runway at Adirondack Regional Airport.
#  | Adirondack_Regional_Airport : 1stRunwayLengthFeet : 6573
# The 1st runway length in feet of Adirondack Regional Airport is 6573.
#  | Adirondack_Regional_Airport : cityServed : Lake_Placid,_New_York
# Lake Placid, N.Y. is served by the Adirondack Regional Airport.
#  | Adirondack_Regional_Airport : cityServed : Lake_Placid,_New_York
# Adirondack Regional Airport serves the city of Lake Placid, New York.
#  | Adirondack_Regional_Airport : cityServed : Saranac_Lake,_New_York
# Adirondack Regional Airport serves the city of Saranac Lake, New York.
#  | Adirondack_Regional_Airport : locationIdentifier : "SLK"
# Adirondack Regional Airport location idenitifier is SLK.
#  | Adirondack_Regional_Airport : locationIdentifier : "SLK"
# SLK is the I.D. of the Adirondack Regional Airport.
#  | Adirondack_Regional_Airport : locationIdentifier : "SLK"
# The Adirondack Regional Airport location identifier is SLK.
#  | Adirondack_Regional_Airport : runwayLength : 1219.0
# The runway length of Adirondack Regional Airport is 1,219.
#  | Adirondack_Regional_Airport : runwayLength : 1219.0
# The runway length at Adirondack Regional Airport is 1219.0.
#  | Adirondack_Regional_Airport : runwayLength : 1219.0
# The runway length of Adirondack Regional Airport is 1219.0.
#  | Adirondack_Regional_Airport : runwayLength : 2003.0
# The runway length of Adirondack Regional Airport is 2003.0.
#  | Adirondack_Regional_Airport : runwayLength : 2003.0
# The length of the runway at Adirondack Regional Airport is 2003.0.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : elevationAboveTheSeaLevel : 610.0
# Adolfo Suárez Madrid-Barajas Airport has an elevation of 610.0 metres above sea level.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : elevationAboveTheSeaLevel : 610.0
# Adolfo Suárez Madrid–Barajas Airport is elevated 610 metres above sea level.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Alcobendas
# Adolfo Suárez Madrid–Barajas Airport is in Alcobendas.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Alcobendas
# Adolfo Suárez Madrid Barajas Airport is found in Alcobendas.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Alcobendas
# Adolfo Suárez Madrid–Barajas Airport is located in Alcobendas.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Madrid
# Adolfo Suárez Madrid–Barajas Airport is found in Madrid.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Madrid
# The Adolfo Suárez Madrid–Barajas Airport is in Madrid.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Madrid
# Adolfo Suarez Madrid-Barajas Aiport is located in Madrid.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Paracuellos_de_Jarama
# Adolfo Suárez Madrid–Barajas Airport can be found in Paracuellos de Jarama.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Paracuellos_de_Jarama
# Adolfo Suarez Madrid-Barajas airport is located at Paracuellos de Jarama.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : location : Paracuellos_de_Jarama
# The Adolfo Suárez Madrid–Barajas Airport is in Paracuellos de Jarama.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : operatingOrganisation : ENAIRE
# The Adolfo Suárez Madrid–Barajas Airport is operated by ENAIRE.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : operatingOrganisation : ENAIRE
# ENAIRE is the operating organisation for Adolfo Suarez Madrid-Barajas airport.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : operatingOrganisation : ENAIRE
# Adolfo Suarez Madrid-Barajas Airport is operated by ENAIRE.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 3500.0
# The runway length of Adolfo Suárez Madrid–Barajas Airport is 3,500.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 3500.0
# The runway length at Adolfo Suarez Madrid-Barajas airport is 3500.0.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 3500.0
# The Adolfo Suárez Madrid–Barajas Airport's runway length is 3500.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4100.0
# The runway length of Adolfo Suárez Madrid–Barajas Airport is 4,100.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4100.0
# The runway length of Adolfo Suarez Madrid-Barajas airport is 4100.0.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4100.0
# The length of the runway at Adolfo Suarez Madrid Barajas Airport is 4100.0.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4349.0
# The runway length of Adolfo Suárez Madrid–Barajas Airport is 4,349.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4349.0
# Adolfo Suárez Madrid–Barajas Airport has a runway that is 4349 metres long.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayLength : 4349.0
# The runway length of Adolfo Suarez Madrid-Barajas Airport is 4349.0.
#  | Adolfo_Suárez_Madrid–Barajas_Airport : runwayName : "18R/36L"
# 18R/36L is the runway name of the Adolfo Suárez Madrid-Barajas Airport.
#  | Afonso_Pena_International_Airport : elevationAboveTheSeaLevelInFeet : 2988
# Afonso Pena International Airport is elevated 2988 feet above sea level.
#  | Afonso_Pena_International_Airport : elevationAboveTheSeaLevelInFeet : 2988
# Afonso Pena International Airport has an elevation above the sea level (in feet) of 2988.
#  | Afonso_Pena_International_Airport : elevationAboveTheSeaLevel : 911.0
# Afonso Pena International airport is located 911 metres above sea level.
#  | Afonso_Pena_International_Airport : elevationAboveTheSeaLevel : 911.0
# Afonso Pena International Airport has the elevation of 911 meters above the sea level.
#  | Afonso_Pena_International_Airport : elevationAboveTheSeaLevel : 911.0
# Afonso Pena International Airport is 911.0 metres above sea level.
#  | Afonso_Pena_International_Airport : location : São_José_dos_Pinhais
# The location of Afonso Pena International airport is Sao Jose dos Pinhais.
#  | Afonso_Pena_International_Airport : location : São_José_dos_Pinhais
# Afonso Pena International Airport is located in São José dos Pinhais.
#  | Afonso_Pena_International_Airport : location : São_José_dos_Pinhais
# Afonso Pena International Airport is located in Sao Jose dos Pinhais.
#  | Afonso_Pena_International_Airport : runwayLength : 1800.0
# The runway length at Afonso Pena International airport is 1800.0.
#  | Afonso_Pena_International_Airport : runwayLength : 1800.0
# The runway at Afonso Pena International Airport is 1800 meters long.
#  | Afonso_Pena_International_Airport : runwayLength : 1800.0
# The runway length of Afonso Pena International Airport is 1800.0.
#  | Afonso_Pena_International_Airport : runwayLength : 2215.0
# Afonso Pena International Airport runway length is 2215.0.
#  | Afonso_Pena_International_Airport : runwayLength : 2215.0
# Afonso Pena International Airport has a runway length of 2215.0.
#  | Afonso_Pena_International_Airport : runwayLength : 2215.0
# The runway length of Afonso Pena International Airport is 2215.0.
#  | Afonso_Pena_International_Airport : runwayName : "11/29"
# Afonso Pena International Airport has the runway name 11/29.
#  | Afonso_Pena_International_Airport : runwayName : "15/33"
# The runway name of Afonso Pena International Airport is 15/33.
#  | Afonso_Pena_International_Airport : runwayName : "15/33"
# 15/33 is the runway name at Afonso Pena International airport.
#  | Afonso_Pena_International_Airport : runwayName : "15/33"
# The Afonso Pena International Airport's runway name is "15/33".
#  | Agra_Airport : iataLocationIdentifier : "AGR"
# Agra Airport IATA Location Identifier is AGR.
#  | Agra_Airport : iataLocationIdentifier : "AGR"
# AGR is the IATA I.D. of the Agra Airport.
#  | Agra_Airport : iataLocationIdentifier : "AGR"
# AGR is the ATA Location Identifier for Agra Airport.
#  | Agra_Airport : icaoLocationIdentifier : "VIAG"
# The location identifier for Agra Airport is VIAG.
#  | Agra_Airport : icaoLocationIdentifier : "VIAG"
# The Agra Airport's ICAO location identifier is "VIAG".
#  | Agra_Airport : icaoLocationIdentifier : "VIAG"
# The ICAO Location Identifier of Agra Airport is VIAG.
#  | Agra_Airport : elevationAboveTheSeaLevel : 167.94
# Agra Airport is elevated 167.94 metres above sea level.
#  | Agra_Airport : elevationAboveTheSeaLevel : 167.94
# The elevation above the sea level (in metres) of Agra Airport is 167.94.
#  | Agra_Airport : location : India
# Agra Airport is in India.
#  | Agra_Airport : location : India
# Agra airport is located in India.
#  | Agra_Airport : location : Uttar_Pradesh
# Agra Airport is in Uttar Pradesh.
#  | Agra_Airport : location : Uttar_Pradesh
# Agra Airport is located in Uttar Pradesh.
#  | Agra_Airport : nativeName : "Kheria Air Force Station"
# Kheria Air Force Station is the native name of Agra Airport.
#  | Agra_Airport : nativeName : "Kheria Air Force Station"
# The native name of Agra Airport is Kheria Air Force Station.
#  | Agra_Airport : operatingOrganisation : Airports_Authority_of_India
# The Airports Authority of India is the operating organisation of Agra Airport.
#  | Agra_Airport : operatingOrganisation : Airports_Authority_of_India
# Agra Airport is operated by the Airports Authority of India.
#  | Agra_Airport : operatingOrganisation : Indian_Air_Force
# The operating organization for Agra Airport is the Indian Air Force.
#  | Agra_Airport : operatingOrganisation : Indian_Air_Force
# The Indian Air Force operates the Agra Airport.
#  | Agra_Airport : operatingOrganisation : Indian_Air_Force
# Agra Airport is operated by the Indian Air Force.
#  | Agra_Airport : runwayLength : 1818.0
# 1818 is the length of the runway of Agra Airport.
#  | Agra_Airport : runwayLength : 1818.0
# The length of the runway at Agra Airport is 1818.0.
#  | Agra_Airport : runwayLength : 2743.0
# Agra Airport's runway length is 2743.0.
#  | Al-Taqaddum_Air_Base : location : Habbaniyah
# Al Taqaddum Air Base is located in Habbaniyah.
#  | Al-Taqaddum_Air_Base : location : Habbaniyah
# The location of Al-Taqaddum Air Base is Habbaniyah.
#  | Al-Taqaddum_Air_Base : locationIdentifier : "MAT"
# The location identifier for Al-Taqaddum air base is MAT.
#  | Al-Taqaddum_Air_Base : locationIdentifier : "MAT"
# The location identifier of Al Taqaddum Air Base is MAT.
#  | Al-Taqaddum_Air_Base : runwayLength : 4019.0
# The runway length of Al-Taqaddum Air Base is 4,019.
#  | Al-Taqaddum_Air_Base : runwayLength : 4019.0
# The runway length of Al-Taqaddum air base is 4019.0.
#  | Al-Taqaddum_Air_Base : runwayLength : 4019.0
# The runway length of Al Taqaddum Air Base is 4019.0.
#  | Al_Asad_Airbase : icaoLocationIdentifier : "ORAA"
# ORAA is the ICAO location identifier of Al Asad Airbase,.
#  | Al_Asad_Airbase : icaoLocationIdentifier : "ORAA"
# The ICAO Location Identifier of Al Asad Airbase is ORAA.
#  | Al_Asad_Airbase : elevationAboveTheSeaLevelInFeet : 618
# Al Asad Airbase is 618 feet above sea level.
#  | Al_Asad_Airbase : elevationAboveTheSeaLevelInFeet : 618
# The Al Asad Airbase is 618 ft above sea level.
#  | Al_Asad_Airbase : elevationAboveTheSeaLevelInFeet : 618
# Al Asad Airbase has an elevation above the sea level (in feet) of 618.
#  | Al_Asad_Airbase : location : "Al Anbar Province, Iraq"
# The Al Asad Airbase is situated in the Al Anbar Province, Iraq.
#  | Al_Asad_Airbase : location : "Al Anbar Province, Iraq"
# Al Asad airbase is located at Al Anbar Province, Iraq.
#  | Al_Asad_Airbase : location : "Al Anbar Province, Iraq"
# Al Asad Airbase is located in Al Anbar Province, Iraq.
#  | Al_Asad_Airbase : location : Iraq
# Al Asad Airbase is found in Iraq.
#  | Al_Asad_Airbase : location : Iraq
# The Al Asad Airbase is in Iraq.
#  | Al_Asad_Airbase : location : Iraq
# Al Asad Airbase is in Iraq.
#  | Al_Asad_Airbase : operatingOrganisation : United_States_Air_Force
# Al Asad Airbase is operated by the United States Air Force.
#  | Al_Asad_Airbase : operatingOrganisation : United_States_Air_Force
# The United States Air Force is the operating organisation for Al Asad airbase.
#  | Al_Asad_Airbase : runwayLength : 3078.48
# The runway length of Al Asad Airbase is 3078.48.
#  | Al_Asad_Airbase : runwayLength : 3078.48
# Al Asad Airbase has a runway length of 3078.48.
#  | Al_Asad_Airbase : runwayLength : 3090.0
# The runway length of Al Asad Airbase is 3090 meters.
#  | Al_Asad_Airbase : runwayLength : 3090.0
# The runway length at Al Asad airbase is 3090.0.
#  | Al_Asad_Airbase : runwayLength : 3090.0
# Al Asad Airbase's runway length is 3090.0.
#  | Al_Asad_Airbase : runwayLength : 3990.0
# The runway length of Al Asad Airbase is 3,990.
#  | Al_Asad_Airbase : runwayLength : 3990.0
# The runway length of Al Asad Airbase is 3990.0.
#  | Al_Asad_Airbase : runwayLength : 3990.0
# The Al Asad Airbase has a runway length of 3990.0.
#  | Al_Asad_Airbase : runwayLength : 3992.88
# The runway length of Al Asad Airbase is 3,992.88.
#  | Al_Asad_Airbase : runwayLength : 3992.88
# 3992.88 is the length of the runway at Al Asad Airbase.
#  | Al_Asad_Airbase : runwayName : "08/26"
# ''08/26'' is the runway name at Al Asad Airbase.
#  | Al_Asad_Airbase : runwayName : "08/26"
# 08/26 is the runway name of the Al Asad Airbase.
#  | Al_Asad_Airbase : runwayName : "08/26"
# The runway name of Al Asad Airbase is 08/26.
#  | Al_Asad_Airbase : runwayName : "09L/27R"
# The runway name of Al Asad Airbase is 09L/27R.
#  | Al_Asad_Airbase : runwayName : "09L/27R"
# The AI Asad Airbase's runway name is "09L/27R".
#  | Al_Asad_Airbase : runwayName : "09R/27L"
# 09R/27L is the runway name at Al Asad airbase.
#  | Al_Asad_Airbase : runwayName : "09R/27L"
# The name of the runway at al Asad Airbase is 09R/27L.
#  | Al_Asad_Airbase : runwayName : "09R/27L"
# Al Asad Airbase has the runway name 09R/27L.
#  | Alcobendas : country : Spain
# Alcobendas is located in Spain.
#  | Alcobendas : country : Spain
# Alcobendas is in Spain.
#  | Alcobendas : isPartOf : Community_of_Madrid
# Alcobendas is part of Community of Madrid.
#  | Alcobendas : isPartOf : Community_of_Madrid
# Alcobendas is part of the community of Madrid.
#  | Alcobendas : leaderParty : People's_Party_(Spain)
# The leader party at Alcobendas is the Peoples Party (Spain).
#  | Alderney : capital : Saint_Anne,_Alderney
# Saint Anne is the capital of Alderney.
#  | Alderney : language : English_language
# The main language spoken on Alderney is English.
#  | Alderney : language : English_language
# The English language is spoken in Alderney.
#  | Alderney : language : English_language
# Alderney uses the English language.
#  | Alderney : leader : Elizabeth_II
# Alderney's leader name is Elizabeth II.
#  | Alderney : leader : Elizabeth_II
# Aldernay's leader is Elizabeth II.
#  | Alderney : leader : Elizabeth_II
# The leader's name of Alderney is Elizabeth II.
#  | Alderney_Airport : 1stRunwaySurfaceType : Asphalt
# The first runway at Alderney Airport is made of asphalt.
#  | Alderney_Airport : 1stRunwaySurfaceType : Asphalt
# The 1st runway at Alderney airport has an asphalt surface.
#  | Alderney_Airport : 1stRunwaySurfaceType : Asphalt
# The 1st runway at Alderney Airport is made from Asphalt.
#  | Alderney_Airport : 1stRunwaySurfaceType : Poaceae
# The surface of the 1st runway at Alderney airport is poaceae.
#  | Alderney_Airport : 1stRunwaySurfaceType : Poaceae
# The 1st runway at Alderney Airport is made from Poaceae.
#  | Alderney_Airport : elevationAboveTheSeaLevel : 88.0
# Alderney Airport is 88 metres above sea level.
#  | Alderney_Airport : elevationAboveTheSeaLevel : 88.0
# The Alderney Airport elevation above the sea level (in meters) is 88.
#  | Alderney_Airport : runwayLength : 497.0
# Alderney Airport has a runway length of 497.0.
#  | Alderney_Airport : runwayLength : 497.0
# The runway length of Alderney Airport is 497.0.
#  | Alderney_Airport : runwayLength : 733.0
# The Alderney Airport runway has a length of 733.0.
#  | Alderney_Airport : runwayLength : 877.0
# The runway length of Alderney Airport is 877.
#  | Alderney_Airport : runwayLength : 877.0
# Alderney Airport's runway has a length of 877.0.
#  | Alderney_Airport : runwayLength : 877.0
# The runway length of Alderney Airport is 877.0.
#  | Alderney_Airport : runwayName : "03/21"
# Alderney Airport runway name is 03/21.
#  | Alderney_Airport : runwayName : "03/21"
# The runway name of Alderney Airport is 03/21.
#  | Alderney_Airport : runwayName : "03/21"
# The runway at Alderney Airport is named 03/21.
#  | Alderney_Airport : runwayName : "08/26"
# 08/26 is the runway name of Alderney Airport.
#  | Alderney_Airport : runwayName : "08/26"
# The runway name of Alderney Airport is 08/26.
#  | Allama_Iqbal_International_Airport : cityServed : Lahore
# Allama Iqbal International Airport serves the city of Lahore.
#  | Allama_Iqbal_International_Airport : cityServed : Lahore
# The city of Lahore is served by Allama Iqbal International airport.
#  | Allama_Iqbal_International_Airport : location : Pakistan
# Allama Iqbal International airport is located in Pakistan.
#  | Allama_Iqbal_International_Airport : location : Punjab,_Pakistan
# Allama Iqbal International Airport is found in Punjab, Pakistan.
#  | Allama_Iqbal_International_Airport : location : Punjab,_Pakistan
# Allama Iqbal International Airport is located in Punjab, Pakistan.
#  | Allama_Iqbal_International_Airport : location : Punjab,_Pakistan
# Allama Iqbal International airport is located in Punjab Pakistan.
#  | Allama_Iqbal_International_Airport : operatingOrganisation : Pakistan_Civil_Aviation_Authority
# The Pakistan Civil Aviation Authority governs the Allama Iqbal International Airport.
#  | Allama_Iqbal_International_Airport : operatingOrganisation : Pakistan_Civil_Aviation_Authority
# The Pakistan Civil Aviation Authority is the operating organisation of the Allama Iqbal International Airport.
#  | Allama_Iqbal_International_Airport : operatingOrganisation : Pakistan_Civil_Aviation_Authority
# Allama Iqbal International Airport is operated by Pakistan Civil Aviation Authority.
#  | Allama_Iqbal_International_Airport : runwayLength : 2900.0
# The runway length of Allama Iqbal International Airport is 2900.0.
#  | Allama_Iqbal_International_Airport : runwayLength : 3310.0
# The runway length of Allama Iqbal International Airport is 3,310.
#  | Allama_Iqbal_International_Airport : runwayLength : 3310.0
# Allama Iqbal International airport has a runway length of 3310.0.
#  | Allama_Iqbal_International_Airport : runwayLength : 3310.0
# The runway length of Allama Iqbal International Airport is 3310.0.
#  | Allama_Iqbal_International_Airport : runwayName : "18L/36R"
# The runway name at Allama Iqbal International airport is 18L/36R.
#  | Allama_Iqbal_International_Airport : runwayName : "18L/36R"
# The Allama Iqbal International Airport's runway name is "18L/36R".
#  | Allama_Iqbal_International_Airport : runwayName : "18L/36R"
# The runway name of Allama Iqbal International Airport is 18L/36R.
#  | Alpena,_Michigan : country : United_States
# Alpena Michigan is a country in United States.
#  | Alpena,_Michigan : country : United_States
# Alpena, Michigan is in the U.S.
#  | Alpena,_Michigan : country : United_States
# Alpena, Michigan is located in the United States.
#  | Alpena_County_Regional_Airport : 1stRunwayLengthFeet : 9001
# The length of the first runway of Alpena County Regional Airport is 9001.
#  | Alpena_County_Regional_Airport : 1stRunwayLengthFeet : 9001
# The first runway length in feet of Alpena County Regional Airport is 9001.
#  | Alpena_County_Regional_Airport : cityServed : Alpena,_Michigan
# Alpena County Regional Airport city served Alpena, Michigan.
#  | Alpena_County_Regional_Airport : cityServed : Alpena,_Michigan
# Alpena County Regional Airport serves the city of Alpena, Michigan.
#  | Alpena_County_Regional_Airport : cityServed : Alpena,_Michigan
# Alpena County Regional Airport serves Alpena, Michigan.
#  | Alpena_County_Regional_Airport : elevationAboveTheSeaLevel : 210
# lpena County Regional Airport elevation above the sea level in metres is 210.
#  | Alpena_County_Regional_Airport : elevationAboveTheSeaLevel : 210
# Alpena County Regional Airport has an elevation of 210 metres above sea level.
#  | Alpena_County_Regional_Airport : elevationAboveTheSeaLevel : 210
# Aplena County Regional Airport is elevated 210 metres above sea level.
#  | Alpena_County_Regional_Airport : location : Maple_Ridge_Township,_Alpena_County,_Michigan
# Alpena County Regional Airport is found in Maple Ridge Township, Alpena County in Michigan.
#  | Alpena_County_Regional_Airport : location : Maple_Ridge_Township,_Alpena_County,_Michigan
# The location of Alpena County Regional Airport is Maple Ridge Township, Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : location : Maple_Ridge_Township,_Alpena_County,_Michigan
# Alpena County Regional Airport is located in Maple Ridge Township, Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : location : Wilson_Township,_Alpena_County,_Michigan
# Alpena County Regional Airport is found in Wilson Township, Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : location : Wilson_Township,_Alpena_County,_Michigan
# Alpena County Regional Airport is located in the Wilson Township, Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : location : Wilson_Township,_Alpena_County,_Michigan
# The location of Alpena County Regional Airport is Wilson Township, Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : locationIdentifier : "APN"
# The location identifier of Alpena County Regional airport is APN.
#  | Alpena_County_Regional_Airport : locationIdentifier : "APN"
# The Alpena County Regional Airport's location id is "APN".
#  | Alpena_County_Regional_Airport : locationIdentifier : "APN"
# The loaction identifier of Alpena County Regional Airport is APN.
#  | Alpena_County_Regional_Airport : owner : Alpena_County,_Michigan
# Alpena Country Regional Airport owner is Alpena Country, Michigan.
#  | Alpena_County_Regional_Airport : owner : Alpena_County,_Michigan
# Alpena County, Michigan is the owner of the Alpena County Regional Airport.
#  | Alpena_County_Regional_Airport : owner : Alpena_County,_Michigan
# The owner of Alpena County Regional Airport is Alpena County, Michigan.
#  | Alpena_County_Regional_Airport : runwayLength : 2744.0
# Alpena County Regional Airport's runway length is 2744.0.
#  | Alpena_County_Regional_Airport : runwayLength : 2744.0
# The Alpena County Regional Airport is 2744 meters long.
#  | Alpena_County_Regional_Airport : runwayLength : 2744.0
# The runway length of Alpena County Regional Airport is 2744.0.
#  | Alpena_County_Regional_Airport : runwayName : "7/25"
# 7/25 is the runway name of Alpena County Regional Airport.
#  | Alpena_County_Regional_Airport : runwayName : "7/25"
# The runway name of Alpena County Regional Airport is 7/25.
#  | Amsterdam : leader : Eberhard_van_der_Laan
# Amsterdam's leader is Eberhard van der Laan.
#  | Amsterdam : leader : Eberhard_van_der_Laan
# Eberhard van der Laan is the name of the leader of Amsterdam.
#  | Amsterdam : leader : Eberhard_van_der_Laan
# The leader of Amsterdam is Eberhard van der Laan.
#  | Amsterdam_Airport_Schiphol : 1stRunwayLengthMetre : 3800
# The length of the first runway at Amsterdam Airport Schiphol is 3800 metres.
#  | Amsterdam_Airport_Schiphol : 1stRunwayLengthMetre : 3800
# The length of the 1st runway at Amsterdam airport Schiphol is 3800 metres.
#  | Amsterdam_Airport_Schiphol : 1stRunwayLengthMetre : 3800
# The length of the first runway at Amsterdam Aiport Schiphol is 3800 meters.
#  | Amsterdam_Airport_Schiphol : 1stRunwaySurfaceType : Asphalt
# The first runway at Amsterdam's Schiphol Airport is made from asphalt.
#  | Amsterdam_Airport_Schiphol : 1stRunwaySurfaceType : Asphalt
# The first runway of Amsterdam Airport Schiphol is made in asphalt.
#  | Amsterdam_Airport_Schiphol : 1stRunwaySurfaceType : Asphalt
# The 1st runway at Amsterdam Airport Schiphol is made from Asphalt.
#  | Amsterdam_Airport_Schiphol : 4thRunwaySurfaceType : "Asphalt"
# The fourth runway at Schiphol Airport in Amsterdam is made of asphalt.
#  | Amsterdam_Airport_Schiphol : 4thRunwaySurfaceType : "Asphalt"
# The 4th runway at Amsterdam Airport Schiphol has a surface of asphalt.
#  | Amsterdam_Airport_Schiphol : 5thRunwayNumber : 18
# Amsterdam Airport Schiphol is 5th runway number 18.
#  | Amsterdam_Airport_Schiphol : 5thRunwayNumber : 18
# 18 is the number of the fifth runway of Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : 5thRunwayNumber : 18
# Amsterdam Schiphols Airport's 5th runway has the number 18.
#  | Amsterdam_Airport_Schiphol : elevationAboveTheSeaLevel : -3.3528
# Amsterdam Airport Schiphol is -3.3528 metres above sea level.
#  | Amsterdam_Airport_Schiphol : elevationAboveTheSeaLevel : -3.3528
# Amsterdam airport Schiphol is -3.3528 above sea level.
#  | Amsterdam_Airport_Schiphol : elevationAboveTheSeaLevel : -3.3528
# Amsterdam Airport Schiphol is at an elevation of -3.3528 from sea level.
#  | Amsterdam_Airport_Schiphol : location : Haarlemmermeer
# Amsterdam's Schiphol Airport is located in Haarlemmermeer.
#  | Amsterdam_Airport_Schiphol : location : Haarlemmermeer
# The Amsterdam Airport Schiphol is in Haarlemmermeer.
#  | Amsterdam_Airport_Schiphol : location : Haarlemmermeer
# Amsterdam Airport Schiphol is located in Haarlemmermeer.
#  | Amsterdam_Airport_Schiphol : operatingOrganisation : Schiphol_Group
# Amsterdam Airport Schiphol operating organization is Schiphol Group.
#  | Amsterdam_Airport_Schiphol : operatingOrganisation : Schiphol_Group
# Schiphol Group operates the Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : operatingOrganisation : Schiphol_Group
# The Amsterdam Airport Schiphol is run by the operation organisation the Schiphol Group.
#  | Amsterdam_Airport_Schiphol : runwayLength : 2014.0
# The runway length at Amsterdam Airport Schiphol is 2014.0 meters.
#  | Amsterdam_Airport_Schiphol : runwayLength : 2014.0
# The runway length at Amsterdam airport, Schiphol is 2014.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 2014.0
# Amsterdam Airport Schiphol's runway length is 2014.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3300.0
# The runway length of Amsterdam airport Schiphol is 3300.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3300.0
# The Amsterdam Airport Schiphol's runway length is 3300.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3300.0
# The runway length of Amsterdam Airport Schiphol is 3300.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3400.0
# The length of the runway at Amsterdam Airport Schiphol is 3400.0 metres.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3400.0
# The runway length at Amsterdam Airport, Schiphol is 3400.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3400.0
# Amsterdam Airport Schiphol's runway length is 3400.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3453.0
# The runway length of Amsterdam's Schiphol Airport is 3,453.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3453.0
# The runway length at Amsterdam Airport Schiphol is 3453.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3453.0
# The runway length of Amsterdam Airport Schiphol is 3453.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3500.0
# Amsterdam's Schiphol Airport has a runway length of 3,500.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3500.0
# The runway length of Amsterdam Airport Schiphol is 3500.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3800.0
# The runway length of Amsterdam Airport is 3800.0 metres.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3800.0
# The runway length at Amsterdam Airport Schiphol is 3800.0.
#  | Amsterdam_Airport_Schiphol : runwayLength : 3800.0
# Amsterdam Airport Schiphol's runway length is 3800.0.
#  | Amsterdam_Airport_Schiphol : runwayName : "04/22 'Oostbaan'"
# Amsterdam Airport Schiphol runway name is 04/22 Ooostbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "04/22 'Oostbaan'"
# 04/22 Oostbaan is the runway name of Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : runwayName : "04/22 'Oostbaan'"
# The runway at Amsterdam Airport Schiphol is 04/22 'Oostbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "09/27 'Buitenveldertbaan'"
# Amsterdam Airport Schiphol runway name is 09/27 Buitenvelderbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "09/27 'Buitenveldertbaan'"
# 09/27 Buitenveldertbaan is the runway name of the Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : runwayName : "09/27 'Buitenveldertbaan'"
# Amsterdam Schiphol Airport has a runway named 09/27 Buitenveldertbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18C/36C 'Zwanenburgbaan'"
# The runway name of Amsterdam's Schiphol Airport is 18C/36C Zwanenburgbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18C/36C 'Zwanenburgbaan'"
# 18C/36C or Zwanenburgbaan are the names for the runway at Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : runwayName : "18C/36C 'Zwanenburgbaan'"
# The runway name of Amsterdam Airport Schiphol is 18C/36C Zwanenburgbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18L/36R 'Aalsmeerbaan'"
# Amserdam Airport Schiphol runway name is 18L/36R Aalsmeerbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18L/36R 'Aalsmeerbaan'"
# 18L/36R Aalsmeerbaan is the runway name of Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : runwayName : "18L/36R 'Aalsmeerbaan'"
# Amsterdam Schiphol Airport has the runway name 18L/36R 'Aalsmeerbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18R/36L 'Polderbaan'"
# 18R/36L Plderbaan is the runway name at Amsterdam Airport Schiphol.
#  | Amsterdam_Airport_Schiphol : runwayName : "18R/36L 'Polderbaan'"
# The runway at Amsterdam Sciphol Airport is called 18R/36L Polderbaan.
#  | Amsterdam_Airport_Schiphol : runwayName : "18R/36L 'Polderbaan'"
# The runway name of Amsterdam Airport Schiphol is 18R/36L Polderbaan.
#  | Andrews_County,_Texas : largestCity : Andrews,_Texas
# The largest city in Andrews County, Texas is Andrews.
#  | Andrews_County,_Texas : largestCity : Andrews,_Texas
# Andrews, Texas is the largest city in Andrews County, Texas.
#  | Andrews_County_Airport : 3rdRunwayLengthFeet : 2939
# The third runway length of Andrews County Airport is 2,939 feet.
#  | Andrews_County_Airport : 3rdRunwayLengthFeet : 2939
# The Andrews County Airport's 3rd runway length in ft is 2939.
#  | Andrews_County_Airport : 3rdRunwayLengthFeet : 2939
# The length of the 3rd runway at Andrews County Airport is 2939 feet.
#  | Andrews_County_Airport : 4thRunwayLengthFeet : 25
# Andrews County Airport is 4th runway length feet of 25.
#  | Andrews_County_Airport : 4thRunwayLengthFeet : 25
# The fourth runway at Andrews County Airport is 25 feet long.
#  | Andrews_County_Airport : 4thRunwayLengthFeet : 25
# Andrews County Airport's 4th runway has a length in feet of 25.
#  | Andrews_County_Airport : 4thRunwaySurfaceType : "Asphalt"
# The fourth runway at Andrews County Airport is made from asphalt.
#  | Andrews_County_Airport : 4thRunwaySurfaceType : "Asphalt"
# The Andrews County Airport fourth runway is made of asphalt.
#  | Andrews_County_Airport : 4thRunwaySurfaceType : "Asphalt"
# The 4th runway at Andrews County Airport is made of Asphalt.
#  | Andrews_County_Airport : location : Texas
# Andrews County Airport is located in Texas.
#  | Andrews_County_Airport : locationIdentifier : "E11"
# Andrews Country Airport location identifier is E11.
#  | Andrews_County_Airport : locationIdentifier : "E11"
# E11 is the location identifier of Andrews County Airport.
#  | Andrews_County_Airport : locationIdentifier : "E11"
# Andrews County Airport is located in E11.
#  | Andrews_County_Airport : runwayLength : 1773.0
# The length of the runway at Andrews County Airport is 1773 metres.
#  | Andrews_County_Airport : runwayLength : 1773.0
# The runway length at Andrews County airport is 1773.0.
#  | Andrews_County_Airport : runwayLength : 1773.0
# Andrews County Airport's runway length is 1773.0.
#  | Andrews_County_Airport : runwayLength : 8.0
# Andrews County Airport runway is 8 meters long.
#  | Andrews_County_Airport : runwayLength : 8.0
# The runway length of Andrews County Airport is 8.0.
#  | Andrews_County_Airport : runwayLength : 8.0
# Andrews County Airport runway length is 8.0.
#  | Andrews_County_Airport : runwayLength : 929.0
# The runway length of Andrews County airport is 929.0.
#  | Andrews_County_Airport : runwayLength : 929.0
# The Andrews County Airport's runway length is 929.
#  | Andrews_County_Airport : runwayName : "16/34"
# Andrews Country Airport's runway name is 16/34.
#  | Andrews_County_Airport : runwayName : "16/34"
# 16/34 is the runway name of Andrews County Airport.
#  | Andrews_County_Airport : runwayName : "2/20"
# The runway name of Andrews County Airport is 2/20.
#  | Andrews_County_Airport : runwayName : "2/20"
# 2/20 is the name of the runway of Andrews County Airport.
#  | Angola_International_Airport : 1stRunwayLengthFeet : 13123
# The length of the first runway at Angola International Airport is 13,123 feet.
#  | Angola_International_Airport : 1stRunwayLengthFeet : 13123
# The first runway of Angola International Airport is 13123 feet long.
#  | Angola_International_Airport : 1stRunwayLengthFeet : 13123
# The 1st runway length in feet of Angola International Airport is 13123.
#  | Angola_International_Airport : 1stRunwayNumber : 5
# Angola International Airport 1st runway is Number 5.
#  | Angola_International_Airport : 1stRunwayNumber : 5
# 5 is the number of the first runway of Angola International Airport.
#  | Angola_International_Airport : 1stRunwayNumber : 5
# Angola International Airport's 1st runway has the number 5.
#  | Angola_International_Airport : elevationAboveTheSeaLevelInMetres : 159
# Angola International airport is 159 metres above sea level.
#  | Angola_International_Airport : elevationAboveTheSeaLevelInMetres : 159
# The Angola International Airport is 159 meters above sea level.
#  | Angola_International_Airport : elevationAboveTheSeaLevelInMetres : 159
# Angola International Airport is 159 metres above the sea level.
#  | Angola_International_Airport : location : Ícolo_e_Bengo
# Angola International Airport is located at Ícolo e Bengo.
#  | Angola_International_Airport : location : Ícolo_e_Bengo
# Angola International airport is located in Icolo e Bengo.
#  | Angola_International_Airport : location : Ícolo_e_Bengo
# Angola International Airport is located in Ícolo e Bengo.
#  | Angola_International_Airport : runwayLength : 3800.0
# The runway length of Angola International Airport is 3,800.
#  | Angola_International_Airport : runwayLength : 3800.0
# The runway at Angola International airport is 3800 long.
#  | Angola_International_Airport : runwayLength : 3800.0
# The runway length of Angola International Airport is 3800.0.
#  | Angola_International_Airport : runwayLength : 4000.0
# 4000ft is the runway length at Angola International Airport.
#  | Angola_International_Airport : runwayLength : 4000.0
# The Angola International Airport is 4000 length.
#  | Angola_International_Airport : runwayLength : 4000.0
# The runway length of Angola International Airport is 4000.0.
#  | Angola_International_Airport : runwayName : "05L/23R"
# The runway at Angola International Airport is called "05L/23R".
#  | Angola_International_Airport : runwayName : "05L/23R"
# 05L/23R is the runway name at Angola International airport.
#  | Angola_International_Airport : runwayName : "05L/23R"
# The runway at Angola International Airport is named 05L/23R.
#  | Angola_International_Airport : runwayName : "South Runway"
# "South Runway" is a runway name at Angola International airport.
#  | Angola_International_Airport : runwayName : "South Runway"
# The runway at Angola International Airport is named South Runway.
#  | Angola_International_Airport : runwayName : "South Runway"
# The name of Angola International Airport runway is "South Runway".
#  | Antwerp : administrativeArrondissement : Arrondissement_of_Antwerp
# Antwerp is admin Arrondissement of Arrondissement.
#  | Antwerp : administrativeArrondissement : Arrondissement_of_Antwerp
# Arrondissement of Antwerp is the administrative arrondissement of Antwerp.
#  | Antwerp : administrativeArrondissement : Arrondissement_of_Antwerp
# The administrative Arrondissement of Antwerp is the Arrondissement of Antwerp.
#  | Antwerp : country : Belgium
# Antwerp is in the country of Belgium.
#  | Antwerp : country : Belgium
# Antwerp is a popular tourist destination in Belgium.
#  | Antwerp : country : Belgium
# Antwerp is in Belgium.
#  | Antwerp : mayor : Bart_De_Wever
# The mayor of Antwerp is Bart De Wever.
#  | Antwerp : mayor : Bart_De_Wever
# Bart De Wever is the mayor of Antwerp.
#  | Antwerp_International_Airport : cityServed : Antwerp
# Antwerp International Airport serves the city of Antwerp.
#  | Antwerp_International_Airport : cityServed : Antwerp
# Antwerp is served by Antwerp International airport.
#  | Antwerp_International_Airport : operatingOrganisation : "Flemish department of Mobility and Public Works"
# Antwerp International Airport operation organization is Flemish department of mobility and public works.
#  | Antwerp_International_Airport : operatingOrganisation : "Flemish department of Mobility and Public Works"
# Flemish Department of Mobility and Public Works operates the Antwerp International Airport.
#  | Antwerp_International_Airport : operatingOrganisation : "Flemish department of Mobility and Public Works"
# The Flemish department of Mobility and Public Works is the operating organisation of Antwerp International Airport.
#  | Antwerp_International_Airport : owner : Flemish_Region
# The owner of Antwerp International Airport is the Flemish Region.
#  | Antwerp_International_Airport : owner : Flemish_Region
# Antwerp International Airport is owned by Flemish Region.
#  | Antwerp_International_Airport : owner : Flemish_Region
# Antwerp International Airport is owned by the Flemish Region.
#  | Antwerp_International_Airport : runwayLength : 1510.0
# The runway length at Antwerp International airport is 1510.0.
#  | Antwerp_International_Airport : runwayLength : 1510.0
# The runway at Antwerp International Airport is 1510 meters.
#  | Antwerp_International_Airport : runwayLength : 1510.0
# The runway length of Antwerp International Airport is 1510.0.
#  | Antwerp_International_Airport : runwayLength : 600.0
# The runway at Antwerp International airport is 600.0 in length.
#  | Antwerp_International_Airport : runwayLength : 600.0
# Antwerp International Airport has a runway length of 600.0.
#  | Antwerp_International_Airport : runwayLength : 600.0
# The runway length of Antwerp International Airport is 600.0.
#  | Appleton,_Wisconsin : isPartOf : Grand_Chute,_Wisconsin
# Appleton, Wisconsin is part of Grand Chute, Wisconsin.
#  | Appleton,_Wisconsin : isPartOf : Kimberly,_Wisconsin
# Appleton, Wisconsin is part of Kimberly, Wisconsin.
#  | Appleton,_Wisconsin : isPartOf : Little_Chute,_Wisconsin
# Appleton, Wisconsin is part of little chute, Wisconsin.
#  | Appleton,_Wisconsin : isPartOf : Little_Chute,_Wisconsin
# Appleton, Wisconsin, is part of Little Chute, Wisconsin.
#  | Appleton,_Wisconsin : isPartOf : Little_Chute,_Wisconsin
# Little Chute, Wisconsin is part of Appleton, Wisconsin.
#  | Appleton_International_Airport : 1stRunwayLengthFeet : 8002
# Appleton International Airport is 1st 8002 runway length.
#  | Appleton_International_Airport : 1stRunwayLengthFeet : 8002
# The first runway of Appleton International Airport has a length of 8002 feet.
#  | Appleton_International_Airport : 1stRunwayLengthFeet : 8002
# The 1st runway length in feet of Appleton International Airport is 8002.
#  | Appleton_International_Airport : cityServed : Appleton,_Wisconsin
# Appletone International Airport city served Appleton, Wisconsin.
#  | Appleton_International_Airport : cityServed : Appleton,_Wisconsin
# Appleton International Airport serves the city of Appleton, Wisconsin.
#  | Appleton_International_Airport : cityServed : Appleton,_Wisconsin
# Appleton, Wisconsin is a city which is served by Appleton International Airport.
#  | Appleton_International_Airport : elevationAboveTheSeaLevel : 280
# Appleton International Airport elevation above the sea level in metres is 280.
#  | Appleton_International_Airport : elevationAboveTheSeaLevel : 280
# Appleton International Airport has an elevation of 280 metres above sea level.
#  | Appleton_International_Airport : elevationAboveTheSeaLevel : 280
# Appleton International Airport is elevated 280 metres above sea level.
#  | Appleton_International_Airport : location : Greenville,_Wisconsin
# Appleton International Airport can be found in Greenville, Wisconsin.
#  | Appleton_International_Airport : location : Greenville,_Wisconsin
# Appleton International airport is located in Greenville, Wisconsin.
#  | Appleton_International_Airport : location : Greenville,_Wisconsin
# The Appleton International Airport is in Greenville, Wisconsin.
#  | Appleton_International_Airport : locationIdentifier : "ATW"
# The location identifier for Appleton International Airport is ATW.
#  | Appleton_International_Airport : locationIdentifier : "ATW"
# The Appleton International Airport's location id is "ATW".
#  | Appleton_International_Airport : locationIdentifier : "ATW"
# The location identifier of Appleton International Airport is ATW.
#  | Appleton_International_Airport : operatingOrganisation : Outagamie_County,_Wisconsin
# The operating organization for Appleton International Airport is in Outagamie County, Wisconsin.
#  | Appleton_International_Airport : operatingOrganisation : Outagamie_County,_Wisconsin
# Outagamie County, Wisconsin is the operating organisation of Appleton International Airport.
#  | Appleton_International_Airport : operatingOrganisation : Outagamie_County,_Wisconsin
# The operators of Appleton International Airport are in Outagamie County, Wisconsin.
#  | Appleton_International_Airport : runwayLength : 1982.0
# The runway length of Appleton International Airport is 1,982.
#  | Appleton_International_Airport : runwayLength : 1982.0
# The runway length at Appleton International airport is 1982.0.
#  | Appleton_International_Airport : runwayLength : 1982.0
# The Appleton International Airport's runway length is 1982.
#  | Appleton_International_Airport : runwayName : "12/30"
# The runway name of Appleton International Airport is 12/30.
#  | Appleton_International_Airport : runwayName : "12/30"
# 12/30 is the runway name of Appleton International Airport.
#  | Appleton_International_Airport : runwayName : "3/21"
# The runway name of Appleton International Airport is 3/21.
#  | Appleton_International_Airport : runwayName : "3/21"
# ...
# 66391 1999 KW4 has the epoch date of 14 July 2004, an escape velocity of zero and a periapsis of 29919600000.0.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres)
# The celestial body known as (66391) 1999 KW4 has an apoapsis of 162164091.8388 km, an orbital period of 16244700.0 and an epoch date of 14 July 2004.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres)
# The epoch date for 66391 1999 KW4, which has an orbital period of 16244700, is 2004-07.14. The apoapsis of 1999KW4 is 162,164,091.8388 kilometres.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres)
# (66391) 1999 KW4 has an apoapsis of 162164091.8388 kilometres and an orbital period of 16244700.0. Its epoch date is July 14th 2004.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : periapsis : 29919600000.0
# The celestial body known as (66391) 1999 KW4 has an orbital period of 16244700, a periapsis of 29919600000.0, and an epoch date of 14 July 2004.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : periapsis : 29919600000.0
# The epoch date for 66391 1999 KW4 was on 2004-07.14 and has an orbital period of 16244700.0 and its periapsis is 29919600000.0.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : orbitalPeriod : 16244700.0 | (66391)_1999_KW4 : periapsis : 29919600000.0
# (66391) 199 KW4 has an epoch date of July 14th 2004. It's orbital period is 16244700 and has a peripsis of 29919600000.0.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : periapsis : 29919600000.0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres)
# (66391) 199 KW4, which has an epoch date of July 14th 2004, has a periapsis of 29919600000.0 and an apoapsis of 162164091.8388 kilometres.
#  | (66391)_1999_KW4 : epoch : 2004-07-14 | (66391)_1999_KW4 : periapsis : 29919600000.0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres)
# The epoch date for 66391 1999 KW4 is 2004-07.14. It has a peripsis of 29919600000.0 and an apoapsis measurement of 162164091.8388 (kilometres).
#  | (66391)_1999_KW4 : escapeVelocity : 0 | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres) | (66391)_1999_KW4 : density : 2.0 (gramPerCubicCentimetres)
# With an escape velocity of 0, (66391) 1999 KW4, has a density of 2.0 gm per cu cm and an apoapsis measurement of 162164091.8388 (kilometres).
#  | 1000_Piazzia : epoch : 2015-06-27 | 1000_Piazzia : formerName : "1967 ED" | 1000_Piazzia : periapsis : 352497000000.0
# On 27 June 2015 the celestial body known as 1000 Piazzia, formerly known as 1967 ED, was discovered. It has a periapsis of 352497000000.0.
#  | 1000_Piazzia : epoch : 2015-06-27 | 1000_Piazzia : mass : 1.1 (kilograms) | 1000_Piazzia : orbitalPeriod : 488160.0
# The epoch of 1000 Piazzia is 2015-06-27. It has a mass of 1.1kg and an orbital period of 488160.0.
#  | 1000_Piazzia : epoch : 2015-06-27 | 1000_Piazzia : mass : 1.1 (kilograms) | 1000_Piazzia : orbitalPeriod : 488160.0
# The epoch of 1000 Piazzia is 2015-06-27. It has a mass of 1.1 kg. and an orbital period of 488160.0.
#  | 1000_Piazzia : formerName : "1923 NZ1951 OB" | 1000_Piazzia : periapsis : 352497000000.0 | 1000_Piazzia : epoch : 2015-06-27
# The 1000 Piazzia ( formally known as 1923 NZ1951 OB ) has a periapsis of 352497000000.0 and an epoch date of 2015-06-27.
#  | 1000_Piazzia : formerName : "1923 NZ1951 OB" | 1000_Piazzia : periapsis : 352497000000.0 | 1000_Piazzia : epoch : 2015-06-27
# The dark asteroid 1000 Piazzia has a periapsis is 352497000000.0 and it was formerly called "1923 NZ1951 OB" and its epoch date was on 2015-06-27.
#  | 1000_Piazzia : formerName : "1923 NZ1951 OB" | 1000_Piazzia : periapsis : 352497000000.0 | 1000_Piazzia : epoch : 2015-06-27
# 1000 Piazzia (formerly "1923 NZ1951 OB"), has a periapsis of 352497000000.0 and the epoch date, 2015-06-27.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "1923 OAA907 XC" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# 1001 Gaussia was formerly known as 1923 OAA907 XC and has an epoch date is 2015-06-27. The orbital period is 5.75 days.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "1923 OAA907 XC" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# 1001 Gaussia, which has an orbital period of 5.75 days, has the former name of 1923 OAA907 XC and an epoch date of 31 July 2016.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "1923 OAA907 XC" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# 1001 Gaussia, which was formerly known as 1923 OAA907 XC, has an epoch date of 2015-06-27 and an orbital period of 5.75 days.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# 1001 Gaussia's(former name:A911 MD) epoch date was 2015-06-27 and its orbital period is 5.75 days.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# 1001 Gaussia's -formerly known as A911 MD ,epoch date was 2015-06-27 and it has an orbital period of 5.75 days.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : orbitalPeriod : 5.75 (days)
# The epoch of 1001 Gaussia is on 31 July 2016. It was formerly called A911 MD and has an orbital period of 5.75 days.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : periapsis : 419113394.55312 (kilometres)
# The celestial body known as 1001 Gaussia was formerly called A911 MD. It has an epoch of 31 July 2016 and a periapsis of 419113394.55312 kilometres.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : periapsis : 419113394.55312 (kilometres)
# The former name of the asteroid 1001 Gaussia, which was discovered on 27 June 2015 and has a periapsis of 419113394.55312 kilometres, was A911 MD.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "A911 MD" | 1001_Gaussia : periapsis : 419113394.55312 (kilometres)
# The celestial body known as 1001 Gaussia (formerly called A911 MD), has a periapsis of 419113394.55312 kilometres and the epoch on 31 July 2016.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : orbitalPeriod : 5.75 (days) | 1001_Gaussia : periapsis : 419113394.55312 (kilometres)
# 1001 Gaussia's epoch date is 2015-06-27. It has an orbital period of 5.75 days and a periapsis of 419113394.55312 kilometres.
#  | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : orbitalPeriod : 5.75 (days) | 1001_Gaussia : periapsis : 419113394.55312 (kilometres)
# The periapsis of 1001 Gaussia, which has the epoch date of 27 June 2015 is 419113394.55312 kms and the orbital period is 5.75 days.
#  | 101_Helena : density : 2.0 (gramPerCubicCentimetres) | 101_Helena : escapeVelocity : 0.0348 (kilometrePerSeconds) | 101_Helena : apoapsis : 441092000.0 (kilometres)
# 101 Helena has a density of 2.0 gram per Cubic centimeters,an escape velocity of 0.0348 km per sec and its apoapsis is 441092000.0 kilometres.
#  | 101_Helena : density : 2.0 (gramPerCubicCentimetres) | 101_Helena : escapeVelocity : 0.0348 (kilometrePerSeconds) | 101_Helena : apoapsis : 441092000.0 (kilometres)
# 101 Helena has a density of 2.0 grams per cubic centimetres,an escape velocity of 0.0348 km/s and its apoapsis is 441092000.0 (kilometres).
#  | 101_Helena : density : 2.0 (gramPerCubicCentimetres) | 101_Helena : escapeVelocity : 0.0348 (kilometrePerSeconds) | 101_Helena : apoapsis : 441092000.0 (kilometres)
# 101 Helena has a density of 2.0 gm per cu cm, an escape velocity of 0.0348 km per sec and an apoapsis of 441092000.0 kms.
#  | 101_Helena : discoverer : James_Craig_Watson | 101_Helena : epoch : 2006-12-31 | James_Craig_Watson : deathPlace : Madison,_Wisconsin
# 31st of December, 2006, is the epoch date for 101 Helena, This asteroid, was discovered by, James Craig Watson, who later died in Madison, Wisconsin.
#  | 101_Helena : discoverer : James_Craig_Watson | 101_Helena : epoch : 2006-12-31 | James_Craig_Watson : deathPlace : Madison,_Wisconsin
# With an epoch of 2006-12-31, 101 Helena, was discovered by James Craig Watson, who died in Madison, Wisconsin.
#  | 101_Helena : discoverer : James_Craig_Watson | 101_Helena : epoch : 2006-12-31 | James_Craig_Watson : deathPlace : Madison,_Wisconsin
# 101 Helena was discovered on 31 December 2006 by James Craig Watson, who later died in Madison, Wisconsin.
#  | 101_Helena : discoverer : James_Craig_Watson | James_Craig_Watson : almaMater : University_of_Michigan | James_Craig_Watson : deathCause : Peritonitis
# 101 Helena was discovered by James Craig Watson, whose alma mater was the University of Michigan. and who died from peritonitis.
#  | 101_Helena : discoverer : James_Craig_Watson | James_Craig_Watson : almaMater : University_of_Michigan | James_Craig_Watson : deathCause : Peritonitis
# 101 Hera was discovered by James Craig Watson who studied at the University of Michigan and later died of peritonitis.
#  | 101_Helena : discoverer : James_Craig_Watson | James_Craig_Watson : almaMater : University_of_Michigan | James_Craig_Watson : deathCause : Peritonitis
# James Craig Watson, who discovered 101 Helena, studied at the University of Michigan and died of peritonitis.
#  | 101_Helena : discoverer : James_Craig_Watson | James_Craig_Watson : almaMater : University_of_Michigan | James_Craig_Watson : deathPlace : Madison,_Wisconsin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 dataset_train=WebNLGDataset(tokenizer=tokenizer)
#       2 dataloader_train=DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
#
# Input In [23], in WebNLGDataset.__init__(self, tokenizer, raw_path, language, data_path, split)
#      43 for src, tgt in zip(full_src_lst, full_tgt_lst):
#      44     print(src)
# ---> 45     src = tokenizer.encode(src)
#      46     if len(src)>512:
#      47         # Truncate
#      48         encoded = src[:511] + [tokenizer.eos_token_id]
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/tokenization_utils_base.py:2226, in PreTrainedTokenizerBase.encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2189 @add_end_docstrings(
#    2190     ENCODE_KWARGS_DOCSTRING,
#    2191     """
#    (...)
#    2209     **kwargs
#    2210 ) -> List[int]:
#    2211     """
#    2212     Converts a string to a sequence of ids (integer), using the tokenizer and vocabulary.
#    2213
#    (...)
#    2224             method).
#    2225     """
# -> 2226     encoded_inputs = self.encode_plus(
#    2227         text,
#    2228         text_pair=text_pair,
#    2229         add_special_tokens=add_special_tokens,
#    2230         padding=padding,
#    2231         truncation=truncation,
#    2232         max_length=max_length,
#    2233         stride=stride,
#    2234         return_tensors=return_tensors,
#    2235         **kwargs,
#    2236     )
#    2238     return encoded_inputs["input_ids"]
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/tokenization_utils_base.py:2556, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2546 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2547 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2548     padding=padding,
#    2549     truncation=truncation,
#    (...)
#    2553     **kwargs,
#    2554 )
# -> 2556 return self._encode_plus(
#    2557     text=text,
#    2558     text_pair=text_pair,
#    2559     add_special_tokens=add_special_tokens,
#    2560     padding_strategy=padding_strategy,
#    2561     truncation_strategy=truncation_strategy,
#    2562     max_length=max_length,
#    2563     stride=stride,
#    2564     is_split_into_words=is_split_into_words,
#    2565     pad_to_multiple_of=pad_to_multiple_of,
#    2566     return_tensors=return_tensors,
#    2567     return_token_type_ids=return_token_type_ids,
#    2568     return_attention_mask=return_attention_mask,
#    2569     return_overflowing_tokens=return_overflowing_tokens,
#    2570     return_special_tokens_mask=return_special_tokens_mask,
#    2571     return_offsets_mapping=return_offsets_mapping,
#    2572     return_length=return_length,
#    2573     verbose=verbose,
#    2574     **kwargs,
#    2575 )
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/tokenization_utils.py:647, in PreTrainedTokenizer._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     638 if return_offsets_mapping:
#     639     raise NotImplementedError(
#     640         "return_offset_mapping is not available when using Python tokenizers. "
#     641         "To use this feature, change your tokenizer to one deriving from "
#    (...)
#     644         "https://github.com/huggingface/transformers/pull/2674"
#     645     )
# --> 647 first_ids = get_input_ids(text)
#     648 second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     650 return self.prepare_for_model(
#     651     first_ids,
#     652     pair_ids=second_ids,
#    (...)
#     666     verbose=verbose,
#     667 )
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/tokenization_utils.py:616, in PreTrainedTokenizer._encode_plus.<locals>.get_input_ids(text)
#     614 def get_input_ids(text):
#     615     if isinstance(text, str):
# --> 616         tokens = self.tokenize(text, **kwargs)
#     617         return self.convert_tokens_to_ids(tokens)
#     618     elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/tokenization_utils.py:547, in PreTrainedTokenizer.tokenize(self, text, **kwargs)
#     545         tokenized_text.append(token)
#     546     else:
# --> 547         tokenized_text.extend(self._tokenize(token))
#     548 # ["This", " is", " something", "<special_token_1>", "else"]
#     549 return tokenized_text
#
# File ~/Developer/Prefix Tuning/mt5-prefix-tuning/transformers/src/transformers/models/t5/tokenization_t5.py:266, in T5Tokenizer._tokenize(self, text)
#     264 def _tokenize(self, text: str) -> List[str]:
#     265     """Take as input a string and return a list of strings (tokens) for words/sub-words"""
# --> 266     return self.sp_model.encode(text, out_type=str)
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/sentencepiece/__init__.py:304, in SentencePieceProcessor.Encode(self, input, out_type, add_bos, add_eos, reverse, enable_sampling, nbest_size, alpha)
#     301 if type(input) is list:
#     302   return [_encode(n) for n in input]
# --> 304 return _encode(input)
#
# File /opt/miniconda3/envs/prefixtuning/lib/python3.9/site-packages/sentencepiece/__init__.py:283, in SentencePieceProcessor.Encode.<locals>._encode(text)
#     281     result = self.SampleEncodeAsPieces(text, nbest_size, alpha)
#     282   else:
# --> 283     result = self.EncodeAsPieces(text)
#     285 if reverse:
#     286   result.reverse()
#
# KeyboardInterrupt:

# %%
class PromptTuning(nn.Module):
    """
    """
    def __init__(self, pretrained_config, prompt_len=20, hidden_dim=256):
        super().__init__()
        
        # Config of Pre-Trained LM
        self.pretrained_config=pretrained_config
        
        # torch.tensor([0, 1, 2, .. , prompt_len-1])
        self.pre_prompt=torch.arange(prompt_len)
        # Embedding
        self.embd=nn.Embedding(num_embeddings=prompt_len, embedding_dim=pretrained_config.d_model)
        # Reparameterization
        self.reparam=nn.Sequential(
            nn.Linear(pretrained_config.d_model, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, pretrained_config.d_model)
        )
        
    def forward(self, batch_size, device):
        # Shape: batch_size, prompt_len
        prompt=self.pre_prompt.unsqueeze(0).expand(batch_size, -1).to(device)
        # Shape: batch_size, prompt_len, d_model
        prompt=self.embd(prompt)
        # Shape: batch_size, prompt_len, d_model
        prompt=self.reparam(prompt)
        
        return prompt

# %%
# Model: Prompt Tuning
model=PromptTuning(pretrained_config=pretrained.config, prompt_len=prompt_len, hidden_dim=hidden_dim)

# Optim, Scheduler
optimizer=AdamW(model.parameters(), lr=lr)
# NO Warm-Up
scheduler=get_linear_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=int(epochs*len(dataset_train)/(accumulation_steps*batch_size))
)

# TensorBoard: Logging
writer=SummaryWriter()
step_global=0

for epoch in range(epochs):
    # Train Phase
    model.train()
    model.to(device)
    
    loss_train=0
    optimizer.zero_grad()
    
    for step, (data, attn_mask, label) in enumerate(dataloader_train):
        data=data.to(device)
        attn_mask=attn_mask.to(device)
        label=label.to(device)
        
        prompt=model(batch_size=data.shape[0] , device=device)
        outputs=pretrained(input_ids=data, attention_mask=attn_mask, labels=label, prompt=prompt)
        
        loss=outputs[0]/accumulation_steps
        loss.backward()
        
        loss_train+=loss.item()
        
        if (step+1)%accumulation_steps==0:
            step_global+=1
            
            # TensorBoard
            writer.add_scalar(
                f'loss_train/MT5-base_Prompt-Tuning_prompt-len{prompt_len}_hidden-dim{hidden_dim}_lr{lr}_batch{int(accumulation_steps*batch_size)}_epoch{epochs}',
                loss_train,
                step_global
            )
            # Console
            if step_global%1000==0:
                print(f'epoch {epoch+1} step {step_global} loss_train {loss_train:.4f}')
            # Set Loss to 0
            loss_train=0
            
            optimizer.step()
            scheduler.step()
            
            optimizer.zero_grad()
            
    # Save Model
    model.to(torch.device('cpu'))
    torch.save(model, f'../model/MT5-base_Prompt-Tuning_prompt-len{prompt_len}_hidden-dim{hidden_dim}_lr{lr}_batch{int(accumulation_steps*batch_size)}_epoch{epoch+1}of{epochs}.pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 # Model: Prompt Tuning
# ----> 2 model=PromptTuning(pretrained_config=pretrained.config, prompt_len=prompt_len, hidden_dim=hidden_dim)
#       4 # Optim, Scheduler
#       5 optimizer=AdamW(model.parameters(), lr=lr)
#
# NameError: name 'PromptTuning' is not defined
